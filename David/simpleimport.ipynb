# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt
import mplfinance as mpf

# %%
#set ticker
appl=yf.Ticker("AAPL")

# %%
# get stock info
appl.info

# get historical market data
hist = appl.history(period="max")

# %%
#download data
data = yf.download("AAPL",
                   start="2015-07-01", 
                   end="2021-07-01",
                   period = "1d"
                  )
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close     Volume
# Date
# 2015-07-01  31.725000  31.735001  31.497499  31.650000  28.973688  120955200
# 2015-07-02  31.607500  31.672501  31.442499  31.610001  28.937071  108844000
# 2015-07-06  31.235001  31.557501  31.212500  31.500000  28.836372  112241600
# 2015-07-07  31.472500  31.537500  30.942499  31.422501  28.765427  187787200
# 2015-07-08  31.120001  31.160000  30.635000  30.642500  28.051380  243046400

# %%
#mpl finance to read the dataframe
mpf.plot(data,type='candle')
# Out:
# C:\Users\dschi\anaconda3\envs\machinelearning\lib\site-packages\mplfinance\_arg_validators.py:35: UserWarning:
#
#  =================================================================
#
#    WARNING: YOU ARE PLOTTING SO MUCH DATA THAT IT MAY NOT BE
#             POSSIBLE TO SEE DETAILS (Candles, Ohlc-Bars, Etc.)
#    For more information see:
#    - https://github.com/matplotlib/mplfinance/wiki/Plotting-Too-Much-Data
#
#    TO SILENCE THIS WARNING, set `type='line'` in `mpf.plot()`
#    OR set kwarg `warn_too_much_data=N` where N is an integer
#    LARGER than the number of data points you want to plot.
#
#  ================================================================
#   warnings.warn('\n\n ================================================================= '+

# %%
#plot slices
mpf.plot(data.iloc[0:5],type='candle')

# %%
#slice with moving average
mpf.plot(data.iloc[0:50],type='candle',mav=4)
